# %% [markdown]
# ## Var declarations

# %%
data_file_path = "/Users/lorenapacheco/Concordia/Masters/BugReportsMining/data/merged_data_production_bug_reports.json"
gzoltar_file_path = "/Users/lorenapacheco/Concordia/Masters/BugReportsMining/data/coverage_data_gzoltar.json"
projects_dir = "/Users/lorenapacheco/Concordia/Masters/open_source_repos_being_studied/"



projects_github = {
    "Cli": "apache/commons-cli",
    "Closure": "google/closure-compiler",
    "Codec": "apache/commons-codec",
    "Collections": "apache/commons-collections",
    "Compress": "apache/commons-compress",
    "Csv": "apache/commons-csv",
    "Gson": "google/gson",
    "JacksonCore": "FasterXML/jackson-core",
    "JacksonDatabind": "FasterXML/jackson-databind",
    "Jsoup": "jhy/jsoup",
    "JxPath": "apache/commons-jxpath",
    "Mockito": "mockito/mockito",
    "Time" : "JodaOrg/joda-time",
    "fastjson": "alibaba/fastjson",
    "junit4": "junit-team/junit4"
}

# %% [markdown]
# ## General methods

# %%
import json
import os

def json_file_to_dict(file):
    data = {}
    with open(os.path.join(file), 'r') as fp:
        data = json.load(fp)
    fp.close()
    return data

def dict_to_json_file(file, dic):
    folder = os.path.dirname(file)
    if not os.path.exists(folder):
        os.makedirs(folder)
    with open(os.path.join(file), 'w') as fp:
        json.dump(dic, fp, sort_keys=True, indent=4)
    fp.close()

def read_file_lines(file_path, project_path):
    with open(project_path+file_path, 'r', encoding='utf-8', errors='ignore') as file:
        lines =file.readlines()
    file.close()
    return lines

# %%
def count_lines_of_code_for_coverage(file_path, project_path, covered_lines, begin_line=0, end_line=-1):

    lines = read_file_lines(file_path, project_path)
    if end_line==-1:
        end_line=len(lines)
    count = 0
    multiline_comment_active = False
    begin_pos = begin_line - 1
    end_pos = end_line - 1

    for i in range(begin_pos, end_pos + 1):
        line = lines[i]

        # If it is covered, it is a code line
        if i + 1 in covered_lines:
            count +=1
            continue

        # Ignore blocks inside multiline comments
        if line.strip().startswith("/*"):
            multiline_comment_active = True
            continue
        if multiline_comment_active:
            if line.strip().endswith("*/"):
                multiline_comment_active = False
            continue
        # Ignore single line comments
        if line.strip().startswith("//"):
            continue

        # Remove end-ine comments
        line = line.split("//")[0]
        # Count non-empty lines
        if line.strip() != "":
            # Ignoring closing braces only lines
            if line.strip() == "}":
                continue

            # Ignoring conditional lines (branches)
            if line.strip().startswith("if ") or line.strip().startswith("else ") or line.strip().startswith("else:"):
                continue

            # Ignoring loop definition lines
            if line.strip().startswith("for ") or line.strip().startswith("while "):
                continue

            # Treating statements with line break
            if line.strip().endswith("{") or line.strip().endswith("}") or line.strip().endswith(";") or line.strip().endswith(","):
                count = count + 1

    return count

bugs_data = json_file_to_dict(data_file_path)
gzoltar_data = json_file_to_dict(gzoltar_file_path)

for project in gzoltar_data.keys():
    print(project)
    repo_name = projects_github[project].split("/")[1]
    for bug_id in gzoltar_data[project].keys():

        # Skipping bugs in which the gzoltar run failed
        # TODO: Run it again in case I have time
        if project=="Closure":
            if bug_id == "143" or bug_id == "152":
                continue

        if project=="Jsoup":
            if bug_id == "6" or bug_id == "34" or bug_id == "5":
                continue
        print(bug_id)
        buggy_code_info = bugs_data[project][bug_id]["buggyMethods"]
        buggy_files = buggy_code_info.keys()

        commit_hash = bugs_data[project][bug_id]["buggy_commit"]
        project_path = projects_dir + repo_name + "/"
        os.chdir(project_path)
        checkout_command = "git checkout  --quiet " + commit_hash
        os.system(checkout_command)

        buggy_files_covered_lines = {}
        buggy_methods_covered_lines = {} # TODO: Implement method level
        for buggy_file in buggy_files:
            buggy_files_covered_lines[buggy_file] = []
            for gzoltar_file in gzoltar_data[project][bug_id].keys():
                if gzoltar_file in buggy_file:
                    for method in gzoltar_data[project][bug_id][gzoltar_file].keys():
                        buggy_files_covered_lines[buggy_file] += gzoltar_data[project][bug_id][gzoltar_file] [method]
                    break
            buggy_file_lines_of_code = count_lines_of_code_for_coverage(buggy_file, project_path, buggy_files_covered_lines[buggy_file])
            buggy_file_coverage_percentage = 100 * len(buggy_files_covered_lines[buggy_file])/buggy_file_lines_of_code
            print(buggy_file + " -  " + str(buggy_file_coverage_percentage))
    # TODO : Check the results
# Out:
# Cli
# 14
# src/java/org/apache/commons/cli2/option/GroupImpl.java -  62.67123287671233
# 5
# src/java/org/apache/commons/cli/Util.java -  62.5
# Closure
# 106
# src/com/google/javascript/jscomp/GlobalNamespace.java -  9.722222222222221
# src/com/google/javascript/rhino/JSDocInfoBuilder.java -  37.5
# 125
# src/com/google/javascript/jscomp/TypeCheck.java -  63.25411334552103
# 2
# src/com/google/javascript/jscomp/TypeCheck.java -  60.81818181818182
# 27
# src/com/google/javascript/rhino/IR.java -  36.56957928802589
# 34
# src/com/google/javascript/jscomp/CodeGenerator.java -  68.26196473551637
# src/com/google/javascript/jscomp/CodePrinter.java -  4.332129963898917
# 37
# src/com/google/javascript/jscomp/NodeTraversal.java -  65.03496503496504
# src/com/google/javascript/jscomp/parsing/IRFactory.java -  24.63186077643909
# 55
# src/com/google/javascript/jscomp/FunctionRewriter.java -  15.508021390374331
# Codec
# 8
# src/java/org/apache/commons/codec/binary/Base64.java -  57.622739018087856
# src/java/org/apache/commons/codec/binary/Base64InputStream.java -  70.37037037037037
# Collections
# 28
# Compress
# 1
# src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java -  53.44827586206897
# 12
# src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveInputStream.java -  58.57740585774059
# 14
# src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java -  56.626506024096386
# 17
# src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java -  63.09012875536481
# 18
# src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveOutputStream.java -  69.23076923076923
# 23
# src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java -  4.72972972972973
# 32
# src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveInputStream.java -  64.46886446886447
# Csv
# 12
# 4
# src/main/java/org/apache/commons/csv/CSVParser.java -  55.39568345323741
# Gson
# 12
# gson/src/main/java/com/google/gson/internal/bind/JsonTreeReader.java -  69.81132075471699
# 8
# gson/src/main/java/com/google/gson/internal/UnsafeAllocator.java -  16.666666666666668
# JacksonCore
# 4
# src/main/java/com/fasterxml/jackson/core/util/TextBuffer.java -  73.6842105263158
# 7
# src/main/java/com/fasterxml/jackson/core/JsonGenerator.java -  36.54390934844193
# src/main/java/com/fasterxml/jackson/core/json/JsonGeneratorImpl.java -  42.22222222222222
# src/main/java/com/fasterxml/jackson/core/json/JsonWriteContext.java -  50.526315789473685
# src/main/java/com/fasterxml/jackson/core/json/UTF8JsonGenerator.java -  58.783120706575076
# src/main/java/com/fasterxml/jackson/core/json/WriterBasedJsonGenerator.java -  61.8129218900675
# JacksonDatabind
# 104
# src/main/java/com/fasterxml/jackson/databind/util/StdDateFormat.java -  6.040268456375839
# 14
# src/main/java/com/fasterxml/jackson/databind/ObjectReader.java -  32.04903677758319
# 15
# src/main/java/com/fasterxml/jackson/databind/ser/BeanSerializerFactory.java -  65.85365853658537
# src/main/java/com/fasterxml/jackson/databind/ser/std/BeanSerializerBase.java -  63.78132118451025
# src/main/java/com/fasterxml/jackson/databind/ser/std/StdDelegatingSerializer.java -  32.95454545454545
# src/main/java/com/fasterxml/jackson/databind/ser/std/StdSerializer.java -  51.48514851485149
# 17
# src/main/java/com/fasterxml/jackson/databind/ObjectMapper.java -  34.29864253393665
# 25
# src/main/java/com/fasterxml/jackson/databind/JavaType.java -  38.58267716535433
# src/main/java/com/fasterxml/jackson/databind/deser/BasicDeserializerFactory.java -  74.36974789915966
# src/main/java/com/fasterxml/jackson/databind/deser/DeserializerCache.java -  65.35087719298245
# src/main/java/com/fasterxml/jackson/databind/deser/std/EnumSetDeserializer.java -  49.01960784313726
# src/main/java/com/fasterxml/jackson/databind/jsontype/impl/TypeDeserializerBase.java -  43.96551724137931
# src/main/java/com/fasterxml/jackson/databind/module/SimpleAbstractTypeResolver.java -  43.333333333333336
# 28
# src/main/java/com/fasterxml/jackson/databind/deser/BeanDeserializer.java -  52.03252032520325
# src/main/java/com/fasterxml/jackson/databind/deser/std/JsonNodeDeserializer.java -  7.594936708860759
# 32
# src/main/java/com/fasterxml/jackson/databind/deser/std/UntypedObjectDeserializer.java -  19.141914191419144
# 58
# src/main/java/com/fasterxml/jackson/databind/deser/BeanDeserializerFactory.java -  34.40233236151604
# src/main/java/com/fasterxml/jackson/databind/util/ClassUtil.java -  14.054054054054054
# 61
# src/main/java/com/fasterxml/jackson/databind/ObjectMapper.java -  8.89132821075741
# src/main/java/com/fasterxml/jackson/databind/jsontype/impl/StdTypeResolverBuilder.java -  26.96629213483146
# 69
# src/main/java/com/fasterxml/jackson/databind/deser/impl/CreatorCollector.java -  21.21212121212121
# 70
# src/main/java/com/fasterxml/jackson/databind/deser/impl/BeanPropertyMap.java -  22.272727272727273
# 72
# 9
# src/main/java/com/fasterxml/jackson/databind/ser/std/StdKeySerializer.java -  31.818181818181817
# src/main/java/com/fasterxml/jackson/databind/ser/std/StdKeySerializers.java -  26.666666666666668
# 90
# src/main/java/com/fasterxml/jackson/databind/deser/BeanDeserializerFactory.java -  10.843373493975903
# src/main/java/com/fasterxml/jackson/databind/deser/ValueInstantiator.java -  0.0
# src/main/java/com/fasterxml/jackson/databind/deser/std/StdValueInstantiator.java -  0.0
# 91
# src/main/java/com/fasterxml/jackson/databind/deser/DeserializerCache.java -  31.89189189189189
# 93
# src/main/java/com/fasterxml/jackson/databind/jsontype/impl/SubTypeValidator.java -  0.0
# 98
# src/main/java/com/fasterxml/jackson/databind/deser/impl/ExternalTypeHandler.java -  0.0
# src/main/java/com/fasterxml/jackson/databind/deser/impl/PropertyValueBuffer.java -  0.0
# Jsoup
# 54
# src/main/java/org/jsoup/helper/W3CDom.java -  22.68041237113402
# 78
# src/main/java/org/jsoup/Connection.java -  0.0
# src/main/java/org/jsoup/helper/DataUtil.java -  56.17283950617284
# 80
# src/main/java/org/jsoup/parser/XmlTreeBuilder.java -  76.13636363636364
# 82
# src/main/java/org/jsoup/helper/DataUtil.java -  60.46511627906977
# 84
# src/main/java/org/jsoup/helper/W3CDom.java -  20.792079207920793
# 90
# src/main/java/org/jsoup/helper/HttpConnection.java -  12.898550724637682
# JxPath
# 5
# src/java/org/apache/commons/jxpath/ri/model/NodePointer.java -  52.91828793774319
# Mockito
# 17
# src/org/mockito/internal/creation/MockSettingsImpl.java -  38.095238095238095
# src/org/mockito/internal/util/MockUtil.java -  51.42857142857143
# 25
# src/org/mockito/internal/creation/MockSettingsImpl.java -  53.63636363636363
# src/org/mockito/internal/creation/settings/CreationSettings.java -  40.78947368421053
# src/org/mockito/internal/stubbing/defaultanswers/ReturnsDeepStubs.java -  55.55555555555556
# src/org/mockito/internal/util/ConsoleMockitoLogger.java -  25.0
# 30
# src/org/mockito/exceptions/Reporter.java -  19.137466307277627
# src/org/mockito/internal/stubbing/defaultanswers/ReturnsSmartNulls.java -  22.22222222222222
# 31
# src/org/mockito/internal/stubbing/defaultanswers/ReturnsSmartNulls.java -  23.529411764705884
# 4
# src/org/mockito/exceptions/Reporter.java -  27.586206896551722
# 5
# src/org/mockito/internal/verification/VerificationOverTimeImpl.java -  52.459016393442624
# Time
# 10
# src/main/java/org/joda/time/base/BaseSingleFieldPeriod.java -  57.02479338842975
